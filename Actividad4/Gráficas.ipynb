# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
df = pd.read_csv("/home/izcabrera/Escritorio/Computacional1/Actividad4/data.dat",sep='\s+')

# %%
import matplotlib.pyplot as plt

# %%
df.columns
# Out:
# Index([u'PRES', u'HGHT', u'TEMP', u'DWPT', u'RELH', u'MIXR', u'DRCT', u'SKNT', u'THTA', u'THTE', u'THTV'], dtype='object')

# %%
df[u'PRES']
# Out:
# 0     863
# 1     860
# 2     850
# 3     846
# 4     833
# 5     822
# 6     727
# 7     714
# 8     700
# 9     687
# 10    676
# 11    660
# 12    611
# 13    586
# 14    583
# ...
# 105    31.0
# 106    30.0
# 107    28.0
# 108    27.0
# 109    26.7
# 110    26.0
# 111    24.5
# 112    24.0
# 113    22.0
# 114    21.6
# 115    20.0
# 116    19.0
# 117    18.0
# 118     NaN
# 119     NaN
# Name: PRES, Length: 120, dtype: float64

# %%
df.head()
# Out:
#    PRES  HGHT  TEMP  DWPT  RELH   MIXR  DRCT  SKNT   THTA   THTE   THTV
# 0   863  1372  21.4  12.4    56  10.59   270     3  307.2  339.5  309.2
# 1   860  1402  22.8  10.8    47   9.54   247     4  309.0  338.4  310.8
# 2   850  1502  23.0  10.0    44   9.15   170     9  310.2  338.6  311.9
# 3   846  1543  22.7   9.9    44   9.13   170    10  310.4  338.7  312.1
# 4   833  1676  21.9   9.6    45   9.07   155    13  310.9  339.1  312.6

# %%
plt.title('Presion vs. Altura')
plt.xlabel('Altura(m)')
plt.ylabel('Presion(hPa)')
plt.plot(df.PRES,df.HGHT)

# %%
plt.title('Altura vs. Presion')
plt.xlabel('Presion(hPa)')
plt.ylabel('Altura (m)')
plt.plot(df.HGHT,df.PRES)

# %%
plt.title('Temperatura vs. Altura')
plt.xlabel('Altura (m)')
plt.ylabel('Temperatura(c)')
plt.plot(df.TEMP,df.HGHT)

# %%
plt.title('Altura vs. Temperatura')
plt.xlabel('Temperatura(c)')
plt.ylabel('Altura (m)')
plt.plot(df.HGHT,df.TEMP)

# %%
plt.title('Temperatura de rocio vs. Altura')
plt.xlabel('Altura (m)')
plt.ylabel('Temperatura(c)')
plt.plot(df.DWPT,df.HGHT)

# %%
plt.title('Altura vs. Temperatura de rocio')
plt.xlabel('Temperatura de rocio(c)')
plt.ylabel('Altura (m)')
plt.plot(df.HGHT,df.DWPT)

# %%
plt.title('Temperatura vs. Temperatura de rocio')
plt.xlabel('Temperatura de rocio (c)')
plt.ylabel('')
plt.plot(df.TEMP,df.DWPT)

# %%
plt.title('Temperatura de rocio vs. Temperatura')
plt.xlabel('Temperatura(c)')
plt.ylabel('Temperatura de rocio(c)')
plt.plot(df.DWPT,df.TEMP)

# %%
plt.plot(df.TEMP, df.HGHT)
plt.plot(df.DWPT,df.HGHT)
